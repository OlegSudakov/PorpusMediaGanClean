# %%
# !cd code/preprocess && python create_training_images.py --image ../../data/berea/berea.npy --edgelength 64 \
--stride 16 --target_name ../../data/berea/berea_train.npy

# %%
# !cd code/pytorch && python cond_main.py --dataset 3D --datapath ../../data/berea/berea_c64_s16.npy --workdir ../../generated \
--imageSize 64 --nz 512 --ngf 64 --ndf 16 --cuda --niter 10000
# Out:
# /opt/conda/envs/py3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Namespace(batchSize=64, beta1=0.5, cuda=True, datapath='../../data/berea/berea_c64_s16.npy', dataset='3D', imageSize=64, lr=0.0002, ndf=16, netD='', netG='', ngf=64, ngpu=1, niter=10000, nz=512, outf='.', samples=128, workdir='../../generated', workers=2)
# Random Seed:  43
# /opt/conda/envs/py3.6/lib/python3.6/site-packages/torch/nn/modules/container.py:13: UserWarning: nn.Container is deprecated. All of it's functionality is now implemented in nn.Module. Subclass that instead.
#   warnings.warn("nn.Container is deprecated. All of it's functionality "
# DCGAN3D_G(
#   (main): Sequential(
# ...
